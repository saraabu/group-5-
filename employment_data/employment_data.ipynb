# %%
import pandas as pd
import numpy as np

#load the employment data for each employment excel file
employment_data = pd.read_excel('employment_data/allhlcn20.xlsx')
employment_data2 = pd.read_excel('employment_data/allhlcn201.xlsx')
employment_data3 = pd.read_excel('employment_data/allhlcn202.xlsx')
employment_data4 = pd.read_excel('employment_data/allhlcn203.xlsx')
employment_data5 = pd.read_excel('employment_data/allhlcn204.xlsx')

# reading the first few lines of each employment data file to understand the data structure
print(employment_data.head())
print(employment_data2.head())
print(employment_data3.head())
print(employment_data4.head())
print(employment_data5.head())
# Out:
#   Area\nCode  St  Cnty  Own  NAICS  Year Qtr Area Type St Name        Area  \
# 0      US000  US   0.0    0     10  2020   A    Nation     NaN  U.S. TOTAL
# 1      US000  US   0.0    1     10  2020   A    Nation     NaN  U.S. TOTAL
# 2      US000  US   0.0    2     10  2020   A    Nation     NaN  U.S. TOTAL
# 3      US000  US   0.0    3     10  2020   A    Nation     NaN  U.S. TOTAL
# 4      US000  US   0.0    5     10  2020   A    Nation     NaN  U.S. TOTAL
#
#             Ownership                  Industry Annual Average Status Code  \
# 0       Total Covered  10 Total, all industries                        NaN
# 1  Federal Government  10 Total, all industries                        NaN
# 2    State Government  10 Total, all industries                        NaN
# 3    Local Government  10 Total, all industries                        NaN
# 4             Private  10 Total, all industries                        NaN
#
# ...

# %%
#select the specific columns relevant to the COIVD-19 data as a whole using the original employment_data
selected_columns = ['Area', 'Annual Average Employment', 'Annual Average Pay']
employment_selected_data =  employment_data[selected_columns]

#display the updated excel file to only include Area, Annual Average Employment, and Annual Average Pay
print(employment_selected_data.head())
# Out:
#          Area  Annual Average Employment  Annual Average Pay
# 0  U.S. TOTAL                  139103773               64021
# 1  U.S. TOTAL                    2928036               85467
# 2  U.S. TOTAL                    4592925               65762
# 3  U.S. TOTAL                   13642800               56884
# 4  U.S. TOTAL                  117940012               64247
